# %% [markdown]
# <a href="https://colab.research.google.com/github/bhoomika-SB/smart-sensor-data-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Create sample sensor data
data = {
    "temperature": [30,32,35,36,38,40,42,39,37,34],
    "humidity": [60,62,63,65,68,70,72,69,66,64]
}

df = pd.DataFrame(data)

# Create alert column
df["alert"] = df["temperature"].apply(lambda x: 1 if x > 38 else 0)

# Plot temperature
plt.plot(df["temperature"])
plt.title("Temperature Trend")
plt.show()

# ML Model
X = df[["temperature","humidity"]]
y = df["alert"]

model = LogisticRegression()
model.fit(X,y)

print("Model trained successfully")
# Out:
# Model trained successfully
